# %%
from nsepython import *   
print(indices)
import datetime
from pynse import *
nse=Nse()
# Out:
# ['NIFTY', 'FINNIFTY', 'BANKNIFTY']

# %%
from datetime import datetime
import os

today = datetime.now()

DATE = today.strftime('%d_%m_%Y')
DATE_DIR = r"C:/Users/Adhaar Sharma/Desktop/"+DATE
if not os.path.exists(DATE_DIR):
    os.mkdir(DATE_DIR)
TIME = today.strftime('%H_%M_%S')
TIME_DIR = DATE_DIR+r"/"+TIME
os.mkdir(TIME_DIR)

# %%
A = nse.info('SBIN')
df1 = pd.DataFrame(A.items())
df1
DF1_DIR = TIME_DIR+r"/nse.info"
if not os.path.exists(DF1_DIR):
    os.mkdir(DF1_DIR)
df1.to_csv(DF1_DIR+'/nse_info.csv')

# %%
nse.update_symbol_list()

# %%
A = fnolist()
df2 = pd.DataFrame({'col':A})
df2
DF2_DIR = TIME_DIR+r"/fnolist"
if not os.path.exists(DF2_DIR):
    os.mkdir(DF2_DIR)
df2.to_csv(DF2_DIR+'/fnolist.csv')

# %%
print(running_status())
# Out:
# False

# %%
nse.market_status()
# Out:
# {'marketState': [{'market': 'Capital Market',
#    'marketStatus': 'Closed',
#    'tradeDate': '27-Oct-2021',
#    'index': 'NIFTY 50',
#    'last': 18268.4,
#    'variation': 143,
#    'percentChange': 0.79,
#    'marketStatusMessage': 'Normal Market has Closed'},
#   {'market': 'Currency',
#    'marketStatus': 'Closed',
#    'tradeDate': '27-Oct-2021',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
#    'marketStatusMessage': 'Market is Closed'},
#   {'market': 'Commodity',
#    'marketStatus': 'Open',
#    'tradeDate': '26-Oct-2021',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
#    'marketStatusMessage': 'Market is Open'},
#   {'market': 'Debt',
#    'marketStatus': 'Closed',
#    'tradeDate': '27-Oct-2021',
#    'index': '',
#    'last': '',
#    'variation': '',
#    'percentChange': '',
#    'marketStatusMessage': 'Market is Closed'}]}

# %%
df4 = nse.pre_open()
df4
DF4_DIR = TIME_DIR+r"/nse.pre_open"
if not os.path.exists(DF4_DIR):
    os.mkdir(DF4_DIR)
df4.to_csv(DF4_DIR+'/nse_pre_open.csv')

# %%
A = nse_blockdeal()
df5 = pd.DataFrame(A.items())
df5
DF5_DIR = TIME_DIR+r"/nse.blockdeal"
if not os.path.exists(DF5_DIR):
    os.mkdir(DF5_DIR)
df5.to_csv(DF5_DIR+'/nse_blockdeal.csv')

# %%
df6 = nse_fiidii()
df6
DF6_DIR = TIME_DIR+r"/nse.fiidii"
if not os.path.exists(DF6_DIR):
    os.mkdir(DF6_DIR)
df6.to_csv(DF6_DIR+'/nse_fiidii.csv')

# %%
#Circular
print(nse_circular("latest"))
print(nse_circular("all"))
# Out:
# [{'content': {'title': 'Latest Circulars Content', 'field_body': None, 'field_latest_circular': [{'field_body': '<p>XBRL based filing of Related Party Transactions for Listed Companies at NSE</p>\r\n', 'name': 'Equity', 'field_nse_circular_date': '06-Sep-2021', 'field_nse_file_attachement': {'url': 'https://static.nseindia.com/s3fs-public/2021-09/NSE_Circular_06092021.pdf', 'desc': ''}, 'field_sebi_circular_date': '06-Sep-2021'}, {'field_body': '<p>Operational Circular for Issue and Listing of Non-convertible Securities, Securitised Debt Instruments, Security Receipts, Municipal Debt Securities and Commercial Paper</p>\r\n', 'name': 'Debt', 'field_nse_circular_date': '11-Aug-2021', 'field_nse_file_attachement': {'url': 'https://static.nseindia.com/s3fs-public/2021-09/NSE_Circular_11082021.pdf', 'desc': ''}, 'field_sebi_circular_date': '10-Aug-2021', 'field_sebi_file_attachement': {'url': 'https://static.nseindia.com/s3fs-public/2021-09/SEBI_Circular_10082021.pdf', 'desc': ''}}], 'field_unique_url': None}, 'id': '2074', 'type': 'latest_circular', 'changed': 'Thu, 09/16/2021 - 13:42'}]
# {'data': [{'fileDept': 'CMPT', 'circNumber': '50112', 'fileExt': 'pdf', 'sub': 'Revised Settlement Calendar for Takeover Offer under Tender Offer Scheme by Tejas Networks Limited', 'cirDate': '20211026', 'cirDisplayDate': 'October 26, 2021', 'circFilename': 'CMPT50112.pdf', 'circFilelink': 'https://archives.nseindia.com/content/circulars/CMPT50112.pdf', 'circCompany': 'NCL', 'circDisplayNo': 'NCL/CMPT/50112', 'circCategory': 'Clearing', 'circDepartment': 'NSE Clearing - Capital Market'}, {'fileDept': 'CML', 'circNumber': '50111', 'fileExt': 'pdf', 'sub': 'Listing of Partly Paid Equity Shares allotted on Rights Basis of Kesoram Industries Limited', 'cirDate': '20211026', 'cirDisplayDate': 'October 26, 2021', 'circFilename': 'CML50111.pdf', 'circFilelink': 'https://archives.nseindia.com/content/circulars/CML50111.pdf', 'circCompany': 'NSE', 'circDisplayNo': 'NSE/CML/50111', 'circCategory': 'Listing', 'circDepartment': 'Listing'}, {'fileDept': 'CML', 'circNumber': '50109', 'fileExt': 'pdf', 'sub': 'Listing of further issues of securities', 'cirDate': '20211026', 'cirDisplayDate': 'October 26, 2021', 'circFilename': 'CML50109.pdf', 'circFilelink': 'https://archives.nseindia.com/content/circulars/CML50109.pdf', 'circCompany': 'NSE', 'circDisplayNo': 'NSE/CML/50109', 'circCategory': 'Listing', 'circDepartment': 'Listing'}, {'fileDept': 'INSP', 'circNumber': '50108', 'fileExt': 'zip', 'sub': 'Cyber Security and Cyber Resilience Audit of Trading Members (TYPE-III)', 'cirDate': '20211026', 'cirDisplayDate': 'October 26, 2021', 'circFilename': 'INSP50108.zip', 'circFilelink': 'https://archives.nseindia.com/content/circulars/INSP50108.zip', 'circCompany': 'NSE', 'circDisplayNo': 'NSE/INSP/50108', 'circCategory': 'Compliance', 'circDepartment': 'Inspection & Compliance'}, {'fileDept': 'INSP', 'circNumber': '50107', 'fileExt': 'pdf', 'sub': 'System Audit of Trading Members (TYPE-III)', 'cirDate': '20211026', 'cirDisplayDate': 'October 26, 2021', 'circFilename': 'INSP50107.pdf', 'circFilelink': 'https://archives.nseindia.com/content/circulars/INSP50107.pdf', 'circCompany': 'NSE', 'circDisplayNo': 'NSE/INSP/50107', 'circCategory': 'Compliance', 'circDepartment': 'Inspection & Compliance'}, {'fileDept': 'CML', 'circNumber': '50106', 'fileExt': 'pdf', 'sub': 'Change in ISIN - ICICI Prudential Mutual Fund - ICICI Prudential S&P BSE 500 ETF - NA', 'cirDate': '20211026', 'cirDisplayDate': 'October 26, 2021', 'circFilename': 'CML50106.pdf', 'circFilelink': 'https://archives.nseindia.com/content/circulars/CML50106.pdf', 'circCompany': 'NSE', 'circDisplayNo': 'NSE/CML/50106', 'circCategory': 'Listing', 'circDepartment': 'Listing'}, {'fileDept': 'CML', 'circNumber': '50105', 'fileExt': 'pdf', 'sub': 'Listing of privately placed securities on the debt segment of the Exchange', 'cirDate': '20211026', 'cirDisplayDate': 'October 26, 2021', 'circFilename': 'CML50105.pdf', 'circFilelink': 'https://archives.nseindia.com/content/circulars/CML50105.pdf', 'circCompany': 'NSE', 'circDisplayNo': 'NSE/CML/50105', 'circCategory': 'Trading', 'circDepartment': 'Debt Segment'}, {'fileDept': 'CML', 'circNumber': '50105', 'fileExt': 'pdf', 'sub': 'Listing of privately placed securities on the debt segment of the Exchange', 'cirDate': '20211026', 'cirDisplayDate': 'October 26, 2021', 'circFilename': 'CML50105.pdf', 'circFilelink': 'https://archives.nseindia.com/content/circulars/CML50105.pdf', 'circCompany': 'NSE', 'circDisplayNo': 'NSE/CML/50105', 'circCategory': 'Listing', 'circDepartment': 'Listing'}, {'fileDept': 'CML', 'circNumber': '50104', 'fileExt': 'pdf', 'sub': 'Listing of further issue of Softtech Engineers Limited', 'cirDate': '20211026', 'cirDisplayDate': 'October 26, 2021', 'circFilename': 'CML50104.pdf', 'circFilelink': 'https://archives.nseindia.com/content/circulars/CML50104.pdf', 'circCompany': 'NSE', 'circDisplayNo': 'NSE/CML/50104', 'circCategory': 'Others', 'circDepartment': 'Emerge'}, {'fileDept': 'CML', 'circNumber': '50104', 'fileExt': 'pdf', 'su ...

# %%
#P-E,Sector
print(nse_eq("JUSTDIAL")['metadata']['pdSectorPe'])
print(nse_eq("JUSTDIAL")['metadata']['pdSectorInd'])
# Out:
# 28.3
# NIFTY 500

# %%
df7 = nse.top_gainers(index=IndexSymbol.FnO, length=10)
df7
DF7_DIR = TIME_DIR+r"/nse.top_gainers"
if not os.path.exists(DF7_DIR):
    os.mkdir(DF7_DIR)
df7.to_csv(DF7_DIR+'/nse_top_gainers.csv')

# %%
df8 = nse.top_losers(index=IndexSymbol.FnO, length=10)
df8
DF8_DIR = TIME_DIR+r"/nse.top_losers"
if not os.path.exists(DF8_DIR):
    os.mkdir(DF8_DIR)
df8.to_csv(DF8_DIR+'/nse_top_losers.csv')

# %%
df9 = nse_get_top_gainers()
df9
DF9_DIR = TIME_DIR+r"/nse.get_top_gainers"
if not os.path.exists(DF9_DIR):
    os.mkdir(DF9_DIR)
df9.to_csv(DF9_DIR+'/nse_get_top_gainers.csv')

# %%
df10 = nse_get_top_losers()
df10
DF10_DIR = TIME_DIR+r"/nse_get_top_losers"
if not os.path.exists(DF10_DIR):
    os.mkdir(DF10_DIR)
df10.to_csv(DF10_DIR+'/nse_get_top_losers.csv')

# %%
df11 = nse_get_advances_declines()
df11
DF11_DIR = TIME_DIR+r"/nse_get_advances_declines"
if not os.path.exists(DF11_DIR):
    os.mkdir(DF11_DIR)
df11.to_csv(DF11_DIR+'/nse_get_advances_declines.csv')

# %%
df12 = nse_results("equities","Quarterly")
df12
DF12_DIR = TIME_DIR+r"/nse_results"
if not os.path.exists(DF12_DIR):
    os.mkdir(DF12_DIR)
df12.to_csv(DF12_DIR+'/nse_results.csv')

# %%
df13 = nse_events()
df13
DF13_DIR = TIME_DIR+r"/nse_results"
if not os.path.exists(DF13_DIR):
    os.mkdir(DF13_DIR)
df13.to_csv(DF13_DIR+'/nse_results.csv')

# %%
df14 = pd.json_normalize(nse_holidays()['FO'])
df14
DF14_DIR = TIME_DIR+r"/nse_holidays"
if not os.path.exists(DF14_DIR):
    os.mkdir(DF14_DIR)
df14.to_csv(DF14_DIR+'/nse_holidays.csv')

# %%
holiday_master(type='trading')
# Out:
# {'CBM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'CD': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'CM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 16},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 17},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 18},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 19}],
#  'CMOT': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 16},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 17},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 18},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 19}],
#  'COM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 2},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 3},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 4},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 5},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 6},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 7},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 8}],
#  'FO': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 16},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 17},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 18},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 19}],
#  'IRD': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'MF': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan',
#    'Sr_no': 16},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 17},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 18},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 19}],
#  'NDM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'NTRP': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'SLBS': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 16},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 17},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 18}]}

# %%
holiday_master(type='clearing')
# Out:
# {'CBM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chhatrapati Shivaji Maharaj Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr. Babasaheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 10},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 11},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 12},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 13},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 14},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 15},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dusshera',
#    'Sr_no': 16},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 17},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali- Laxmi Pujan',
#    'Sr_no': 18},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 19},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 20}],
#  'CD': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chhatrapati Shivaji Maharaj Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr. Babasaheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 10},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 11},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 12},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 13},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 14},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 15},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dusshera',
#    'Sr_no': 16},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 17},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali- Laxmi Pujan',
#    'Sr_no': 18},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 19},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 20}],
#  'CM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chhatrapati Shivaji Maharaj Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr. Babasaheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 10},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 11},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 12},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 13},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 14},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 15},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dusshera',
#    'Sr_no': 16},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 17},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali- Laxmi Pujan',
#    'Sr_no': 18},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 19},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 20}],
#  'COM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chhatrapati Shivaji Maharaj Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr. Babasaheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 10},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 11},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 12},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 13},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 14},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 15},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dusshera',
#    'Sr_no': 16},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 17},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali- Laxmi Pujan',
#    'Sr_no': 18},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 19},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 20}],
#  'FO': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chhatrapati Shivaji Maharaj Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr. Babasaheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 10},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 11},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 12},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 13},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 14},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 15},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dusshera',
#    'Sr_no': 16},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 17},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali- Laxmi Pujan',
#    'Sr_no': 18},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 19},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 20}],
#  'IRD': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chhatrapati Shivaji Maharaj Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr. Babasaheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 10},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 11},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 12},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 13},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 14},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 15},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dusshera',
#    'Sr_no': 16},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 17},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali- Laxmi Pujan',
#    'Sr_no': 18},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 19},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 20}],
#  'MF': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chhatrapati Shivaji Maharaj Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr. Babasaheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 10},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 11},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 12},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 13},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 14},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 15},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dusshera',
#    'Sr_no': 16},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 17},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali- Laxmi Pujan',
#    'Sr_no': 18},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 19},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 20}],
#  'NDM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chhatrapati Shivaji Maharaj Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr. Babasaheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 10},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 11},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 12},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 13},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 14},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 15},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dusshera',
#    'Sr_no': 16},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 17},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali- Laxmi Pujan',
#    'Sr_no': 18},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 19},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 20}],
#  'SLBS': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chhatrapati Shivaji Maharaj Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr. Babasaheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 10},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 11},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 12},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 13},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 14},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 15},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dusshera',
#    'Sr_no': 16},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 17},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali- Laxmi Pujan',
#    'Sr_no': 18},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 19},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 20}]}

# %%
nse_holidays(type='trading')
# Out:
# {'CBM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'CD': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'CM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 16},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 17},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 18},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 19}],
#  'CMOT': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 16},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 17},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 18},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 19}],
#  'COM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 2},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 3},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 4},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 5},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 6},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 7},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 8}],
#  'FO': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 16},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 17},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 18},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 19}],
#  'IRD': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan*',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'MF': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan',
#    'Sr_no': 16},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 17},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 18},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 19}],
#  'NDM': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'NTRP': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '19-Feb-2021',
#    'weekDay': 'Friday',
#    'description': 'Chatrapati Shivaji Jayanti',
#    'Sr_no': 2},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 3},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 4},
#   {'tradingDate': '01-Apr-2021',
#    'weekDay': 'Thursday',
#    'description': 'Annual Bank Closing',
#    'Sr_no': 5},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 6},
#   {'tradingDate': '13-Apr-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Gudi Padwa',
#    'Sr_no': 7},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 8},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 9},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 10},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 11},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 12},
#   {'tradingDate': '26-May-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Buddha Pournima',
#    'Sr_no': 13},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 14},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 15},
#   {'tradingDate': '16-Aug-2021',
#    'weekDay': 'Monday',
#    'description': 'Parsi New Year',
#    'Sr_no': 16},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 17},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 18},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 19},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 20},
#   {'tradingDate': '19-Oct-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Id-E-Milad',
#    'Sr_no': 21},
#   {'tradingDate': '04-Nov-2021',
#    'weekDay': 'Thursday',
#    'description': 'Diwali-Laxmi Pujan',
#    'Sr_no': 22},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 23},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 24},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 25}],
#  'SLBS': [{'tradingDate': '26-Jan-2021',
#    'weekDay': 'Tuesday',
#    'description': 'Republic Day',
#    'Sr_no': 1},
#   {'tradingDate': '11-Mar-2021',
#    'weekDay': 'Thursday',
#    'description': 'Mahashivratri',
#    'Sr_no': 2},
#   {'tradingDate': '29-Mar-2021',
#    'weekDay': 'Monday',
#    'description': 'Holi',
#    'Sr_no': 3},
#   {'tradingDate': '02-Apr-2021',
#    'weekDay': 'Friday',
#    'description': 'Good Friday',
#    'Sr_no': 4},
#   {'tradingDate': '14-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Dr.Baba Saheb Ambedkar Jayanti',
#    'Sr_no': 5},
#   {'tradingDate': '21-Apr-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Ram Navami',
#    'Sr_no': 6},
#   {'tradingDate': '25-Apr-2021',
#    'weekDay': 'Sunday',
#    'description': 'Mahavir Jayanti',
#    'Sr_no': 7},
#   {'tradingDate': '01-May-2021',
#    'weekDay': 'Saturday',
#    'description': 'Maharashtra Day',
#    'Sr_no': 8},
#   {'tradingDate': '13-May-2021',
#    'weekDay': 'Thursday',
#    'description': 'Id-Ul-Fitr (Ramzan ID)',
#    'Sr_no': 9},
#   {'tradingDate': '21-Jul-2021',
#    'weekDay': 'Wednesday',
#    'description': 'Bakri Id',
#    'Sr_no': 10},
#   {'tradingDate': '15-Aug-2021',
#    'weekDay': 'Sunday',
#    'description': 'Independence Day',
#    'Sr_no': 11},
#   {'tradingDate': '19-Aug-2021',
#    'weekDay': 'Thursday',
#    'description': 'Moharram',
#    'Sr_no': 12},
#   {'tradingDate': '10-Sep-2021',
#    'weekDay': 'Friday',
#    'description': 'Ganesh Chaturthi',
#    'Sr_no': 13},
#   {'tradingDate': '02-Oct-2021',
#    'weekDay': 'Saturday',
#    'description': 'Mahatma Gandhi Jayanti',
#    'Sr_no': 14},
#   {'tradingDate': '15-Oct-2021',
#    'weekDay': 'Friday',
#    'description': 'Dussehra',
#    'Sr_no': 15},
#   {'tradingDate': '05-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Diwali-Balipratipada',
#    'Sr_no': 16},
#   {'tradingDate': '19-Nov-2021',
#    'weekDay': 'Friday',
#    'description': 'Gurunanak Jayanti',
#    'Sr_no': 17},
#   {'tradingDate': '25-Dec-2021',
#    'weekDay': 'Saturday',
#    'description': 'Christmas',
#    'Sr_no': 18}]}
